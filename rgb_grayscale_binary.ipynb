# %%
from PIL import Image
from rgb_grayscale_binary import convert_rgb_to_grayscale, convert_grayscale_to_binary
from util import display_image
# %load_ext autoreload
# %autoreload 2


# Load the RGB image
rgb_image = Image.open("image.jpg")

grayscale_image = convert_rgb_to_grayscale(rgb_image)

display_image([grayscale_image], 1,1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <PIL.Image.Image image mode=RGB size=415x415>

# %%
binary_image = convert_grayscale_to_binary(grayscale_image)

display_image([binary_image], 1, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=415x415>
