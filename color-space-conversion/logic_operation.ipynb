# %%
from PIL import Image
from logic_operation import operate_logical_not, operate_logical_operation
from util import display_image
# %load_ext autoreload
# %autoreload 2

# Load the RGB images
triangle_image = Image.open("triangle.jpg")
circle_image = Image.open("circle.jpg")


and_image = operate_logical_operation(triangle_image, circle_image, "AND")
or_image = operate_logical_operation(triangle_image, circle_image, "OR")
xor_image = operate_logical_operation(triangle_image, circle_image, "XOR")
not_image = operate_logical_not(triangle_image)
nand_image = operate_logical_operation(triangle_image, circle_image, "NAND")
nor_image = operate_logical_operation(triangle_image, circle_image, "NOR")
xnor_image = operate_logical_operation(triangle_image, circle_image, "XNOR")

display_image([triangle_image, circle_image, and_image], 3, 1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <PIL.Image.Image image mode=RGB size=1800x600>

# %%
display_image([triangle_image, circle_image, or_image], 3, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1800x600>

# %%
display_image([triangle_image, circle_image, xor_image], 3, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1800x600>

# %%
display_image([triangle_image, not_image], 2, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x600>

# %%
display_image([triangle_image, circle_image, nand_image], 3, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1800x600>

# %%
display_image([triangle_image, circle_image, nor_image], 3, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1800x600>

# %%
display_image([triangle_image, circle_image, xnor_image], 3, 1)
# Out:
# <PIL.Image.Image image mode=RGB size=1800x600>
