# %%
from PIL import Image
from rgb_yiq import convert_rgb_to_yiq, remove_yiq_attributes, rgb_to_yiq, yiq_to_rgb
from util import display_image
from rgb_cmyk import convert_rgb_to_cmyk, remove_cmyk_attribute
# %load_ext autoreload
# %autoreload 2

# Load the RGB image
rgb_image = Image.open("image.jpg")
yiq_image = convert_rgb_to_yiq(rgb_image)

only_y_image = remove_yiq_attributes(yiq_image, input_y=True)
only_i_image = remove_yiq_attributes(yiq_image, input_i=True)
only_q_image = remove_yiq_attributes(yiq_image, input_q=True)

y_i_image = remove_yiq_attributes(yiq_image, input_y=True, input_i=True)
y_q_image = remove_yiq_attributes(yiq_image, input_y=True, input_q=True)
i_q_image = remove_yiq_attributes(yiq_image, input_i=True, input_q=True)
y_i_q_image = remove_yiq_attributes(yiq_image, input_y=True, input_i=True, input_q=True)


display_image([only_y_image, only_i_image, only_q_image, y_i_image, y_q_image, i_q_image, y_i_q_image], 7,1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <PIL.Image.Image image mode=RGB size=2905x415>
